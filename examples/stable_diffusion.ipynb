# %%
from diffusers import StableDiffusionPipeline
from IPython.display import Image
from helpers import get_gpu
device = get_gpu()
pipeline = StableDiffusionPipeline.from_pretrained("stable-diffusion-v1-4").to(device)
image = pipeline(input("Enter prompt:"), height=512, width=768).images[0]
image.save("output.png")
Image("output.png")
# Out:
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# The config attributes {'scaling_factor': 0.18215} were passed to AutoencoderKL, but are not expected and will be ignored. Please verify your config.json configuration file.
# Enter prompt: a horse sized cat eating a bagel
#   0%|          | 0/50 [00:00<?, ?it/s]
